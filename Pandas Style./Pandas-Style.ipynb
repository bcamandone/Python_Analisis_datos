# %% [markdown]
#  ## 🐼 Transformando nuestro dataset con estilo😎

# %%
import pandas as pd
import numpy as np

# %%
data1 = pd.read_csv("u.data.txt",sep="\t",header=None)

# %%
data1.columns = ["user_id","item_id","rating","timestamp"]

# %%
data1 = data1.drop("timestamp", axis=1)

# %%
data1.head()
# Out:
#    user_id  item_id  rating
# 0      196      242       3
# 1      186      302       3
# 2       22      377       1
# 3      244       51       2
# 4      166      346       1

# %%
data2 = data1.iloc[:20]

# %%
data2.shape
# Out:
# (20, 3)

# %%
headers = {
    'selector': 'th.col_heading',
    'props': 'background-color: #5E17EB; color: white;'
}

index_style = {
    'selector': 'th.index_name',
    'props': 'background-color: #5E17EB; color: white;'
}

data2_style = (
    data2
        .style
            .set_table_styles([headers,index_style])
            .set_properties(**{'background-color': '#FFCFC9','color': 'black'})
)

data2_style
# Out:
# <style type="text/css">
# #T_02267 th.col_heading {
#   background-color: #5E17EB;
#   color: white;
# }
# #T_02267 th.index_name {
#   background-color: #5E17EB;
#   color: white;
# }
# ...

# %% [markdown]
# ![18.png](attachment:18.png)

# %%
columns = data2.columns[data2.columns.str.startswith('rating')]

max_value = data2[columns].max().max()
min_value = data2[columns].min().min()
# Establecer el estilo para la celda con el valor máximo
max_style =  f'background-color:#3BE8B0; '    
# Establecer el estilo para la celda con el valor mínimo
min_style = f'background-color: #FF66C4; '
(
 data2
 .style
 .set_table_styles([headers])
 .applymap(lambda x: max_style if x == max_value else '')
 .applymap(lambda x: min_style if x == min_value else '', subset=columns)
)
# Out:
# <style type="text/css">
# #T_1bd6f th.col_heading {
#   background-color: #5E17EB;
#   color: white;
# }
# #T_1bd6f_row2_col2, #T_1bd6f_row4_col2 {
#   background-color: #FF66C4;
# }
# #T_1bd6f_row7_col2, #T_1bd6f_row11_col2, #T_1bd6f_row12_col2, #T_1bd6f_row16_col2 {
#   background-color: #3BE8B0;
# }
# </style>
# <table id="T_1bd6f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1bd6f_level0_col0" class="col_heading level0 col0" >user_id</th>
#       <th id="T_1bd6f_level0_col1" class="col_heading level0 col1" >item_id</th>
#       <th id="T_1bd6f_level0_col2" class="col_heading level0 col2" >rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1bd6f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1bd6f_row0_col0" class="data row0 col0" >196</td>
#       <td id="T_1bd6f_row0_col1" class="data row0 col1" >242</td>
#       <td id="T_1bd6f_row0_col2" class="data row0 col2" >3</td>
#     </tr>
# ...

# %% [markdown]
# ![19.png](attachment:19.png)

# %%
(
    data2
        .style
            .set_table_styles([headers, index_style])
            .background_gradient(cmap='Reds',subset=columns)
)
# Out:
# <style type="text/css">
# #T_00a2d th.col_heading {
#   background-color: #5E17EB;
#   color: white;
# }
# #T_00a2d th.index_name {
#   background-color: #5E17EB;
#   color: white;
# }
# #T_00a2d_row0_col2, #T_00a2d_row1_col2, #T_00a2d_row8_col2, #T_00a2d_row9_col2, #T_00a2d_row13_col2, #T_00a2d_row14_col2, #T_00a2d_row15_col2 {
#   background-color: #fb694a;
#   color: #f1f1f1;
# }
# #T_00a2d_row2_col2, #T_00a2d_row4_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_00a2d_row3_col2, #T_00a2d_row6_col2, #T_00a2d_row10_col2, #T_00a2d_row17_col2, #T_00a2d_row19_col2 {
#   background-color: #fcbba1;
#   color: #000000;
# }
# #T_00a2d_row5_col2, #T_00a2d_row18_col2 {
#   background-color: #ca181d;
#   color: #f1f1f1;
# }
# #T_00a2d_row7_col2, #T_00a2d_row11_col2, #T_00a2d_row12_col2, #T_00a2d_row16_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_00a2d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %% [markdown]
# ![20.png](attachment:20.png)

# %% [markdown]
# [Pandas Documentación](https://pandas.pydata.org/docs/user_guide/style.html)

# %% [markdown]
# ## by María Belén Camandone
